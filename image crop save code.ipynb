# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#img=cv2.imread('./data/png.png')
img=cv2.imread('png.png')
plt.imshow(img);
plt.show()

# %%
img.shape
# Out:
# (950, 1108, 3)

# %%
img1=img[0:600,300:800]
plt.imshow(img1)
plt.show()

# %%
img2=cv2.imread('png.png',0)
plt.imshow(img2)
plt.show()
plt.imsave('out.png',img2)

# %%
img3=cv2.GaussianBlur(img2,(3,3),0)
plt.imshow(img3)
plt.show()
