# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#img=cv2.imread('./data/png.png')
img=cv2.imread('png.png')
plt.imshow(img);
plt.show()
img.shape
img1=img[0:600,300:800]
plt.imshow(img1)
plt.show()
img2=cv2.imread('png.png',0)
plt.imshow(img2)
plt.show()
plt.imsave('out1.png',img2)

# %%
img3=cv2.Canny(img2,threshold1=30,threshold2=100)
plt.imshow(img3)
plt.show()
